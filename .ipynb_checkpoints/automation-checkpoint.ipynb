# %%
# Importações
from selenium import webdriver
from selenium.webdriver.common.by import By
import pandas as pd
import time


# Conectando o Selenium ao navegador e conectando o site para automação
driver = webdriver.Chrome()
driver.get("https://www.rpachallenge.com/")

# Importando a planilha
data = pd.read_excel("challenge.xlsx")

# Pegando o elemento pai
form = driver.find_elements(
    By.CSS_SELECTOR, 
    "body > app-root > div.body.row1.scroll-y > app-rpa1 > div > div.inputFields.col.s6.m6.l6 > form"
)


# Laço que irá armazenar os valores da planilha e transferir para o formulário
for i, firstName in enumerate(data["First Name"]):
   
    # Sincronizando as colunas e linhas
    lastName = data.loc[i, "Last Name"]
    number = data.loc[i, "Phone Number"]
    email = data.loc[i, "Email"]
    address = data.loc[i, "Address"]
    companyName = data.loc[i, "Company Name"]
    roleCompany = data.loc[i, "Role in Company"]
    
    
    
    inputAddress = driver.find_element(By.CSS_SELECTOR, '[ng-reflect-name="labelAddress"]').send_keys(address)
    time.sleep(2)
    
    inputFName = driver.find_element(By.CSS_SELECTOR, '[ng-reflect-name="labelFirstName"]').send_keys(firstName)
    time.sleep(2)
    
    inputLName = driver.find_element(By.CSS_SELECTOR, '[ng-reflect-name="labelLastName"]').send_keys(lastName)
    
    inputNumber = driver.find_element(By.CSS_SELECTOR, '[ng-reflect-name="labelPhone"]').send_keys(str(number))
    time.sleep(2)
    
    inputEmail = driver.find_element(By.CSS_SELECTOR, '[ng-reflect-name="labelEmail"]').send_keys(email)
    time.sleep(2)
    
    inputCompany = driver.find_element(By.CSS_SELECTOR, '[ng-reflect-name="labelCompanyName"]').send_keys(companyName)
    time.sleep(2)
    
    inputRoleCompany = driver.find_element(By.CSS_SELECTOR, '[ng-reflect-name="labelRole"]').send_keys(roleCompany)
    time.sleep(2)
    
    inputButton = driver.find_element(By.CSS_SELECTOR, "body > app-root > div.body.row1.scroll-y > app-rpa1 > div > div.inputFields.col.s6.m6.l6 > form > input")
    inputButton.click()
    

    
time.sleep(3)
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Last Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
display(data)
# Out:
#   First Name Last Name    Company Name   Role in Company  \
# 0       John      Smith   IT Solutions           Analyst
# 1       Jane     Dorsey       MediCare  Medical Engineer
# 2     Albert    Kipling     Waterfront        Accountant
# 3    Michael  Robertson       MediCare     IT Specialist
# 4       Doug    Derrick  Timepath Inc.           Analyst
# 5     Jessie    Marlowe  Aperture Inc.         Scientist
# 6       Stan       Hamm      Sugarwell           Advisor
# 7   Michelle     Norton  Aperture Inc.         Scientist
# 8      Stacy     Shelby        TechDev        HR Manager
# 9       Lara     Palmer  Timepath Inc.        Programmer
#
#                   Address                     Email  Phone Number
# 0           98 North Road  jsmith@itsolutions.co.uk   40716543298
# 1         11 Crown Street            jdorsey@mc.com   40791345621
# 2         22 Guild Street    kipling@waterfront.com   40735416854
# 3      17 Farburn Terrace         mrobertson@mc.com   40733652145
# ...
